# %%
import pandas as pd
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
file = 'File'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
colones = ["symboling","normalized-losses", "make"," fuel-type","aspiration"
           "aspiration","body-style","drive-wheels", "engine-location","wheel-base"
          ," length"," width","jheight","curb-weigh","engine-type"," num-of-cylinders","engine-size"
          ,"fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg"," price",]

# %%
colones
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  ' fuel-type',
#  'aspirationaspiration',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  ' length',
#  ' width',
#  'jheight',
#  'curb-weigh',
#  'engine-type',
#  ' num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  ' price']

# %%
df = pd.read_csv(file, header = None, names = colones)
df.head()
# Out:
#   symboling normalized-losses make  fuel-type aspirationaspiration  \
# 3         ?       alfa-romero  gas        std                  two
# 3         ?       alfa-romero  gas        std                  two
# 1         ?       alfa-romero  gas        std                  two
# 2       164              audi  gas        std                 four
# 2       164              audi  gas        std                 four
#
#     body-style drive-wheels engine-location  wheel-base   length  ...  \
# 3  convertible          rwd           front        88.6    168.8  ...
# 3  convertible          rwd           front        88.6    168.8  ...
# 1    hatchback          rwd           front        94.5    171.2  ...
# 2        sedan          fwd           front        99.8    176.6  ...
# 2        sedan          4wd           front        99.4    176.6  ...
#
#    engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# ...

# %%
df.tail(10)
# Out:
#    symboling normalized-losses    make  fuel-type aspirationaspiration  \
# -1        74             volvo     gas        std                 four
# -2       103             volvo     gas        std                 four
# -1        74             volvo     gas        std                 four
# -2       103             volvo     gas      turbo                 four
# -1        74             volvo     gas      turbo                 four
# -1        95             volvo     gas        std                 four
# -1        95             volvo     gas      turbo                 four
# -1        95             volvo     gas        std                 four
# -1        95             volvo  diesel      turbo                 four
# -1        95             volvo     gas      turbo                 four
#
#    body-style drive-wheels engine-location  wheel-base   length  ...  \
# -1      wagon          rwd           front       104.3    188.8  ...
# ...

# %%
df.to_csv('automobile.csv', index = False)

# %%
automobile = pd.read_csv('automobile.csv')
automobile.head()
# Out:
#   symboling normalized-losses make  fuel-type aspirationaspiration  \
# 0         ?       alfa-romero  gas        std                  two
# 1         ?       alfa-romero  gas        std                  two
# 2         ?       alfa-romero  gas        std                  two
# 3       164              audi  gas        std                 four
# 4       164              audi  gas        std                 four
#
#     body-style drive-wheels engine-location  wheel-base   length  ...  \
# 0  convertible          rwd           front        88.6    168.8  ...
# 1  convertible          rwd           front        88.6    168.8  ...
# 2    hatchback          rwd           front        94.5    171.2  ...
# 3        sedan          fwd           front        99.8    176.6  ...
# 4        sedan          4wd           front        99.4    176.6  ...
#
#    engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# ...

# %%
automobile.shape
# Out:
# (205, 25)

# %%
automobile.dtypes
# Out:
# symboling                object
# normalized-losses        object
# make                     object
#  fuel-type               object
# aspirationaspiration     object
# body-style               object
# drive-wheels             object
# engine-location          object
# wheel-base              float64
#  length                 float64
#  width                  float64
# jheight                 float64
# curb-weigh                int64
# engine-type              object
#  num-of-cylinders        object
# engine-size               int64
# fuel-system              object
# bore                     object
# stroke                   object
# compression-ratio       float64
# horsepower               object
# peak-rpm                 object
# city-mpg                  int64
# highway-mpg               int64
#  price                   object
# dtype: object

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   symboling             205 non-null    object
#  1   normalized-losses     205 non-null    object
#  2   make                  205 non-null    object
#  3    fuel-type            205 non-null    object
#  4   aspirationaspiration  205 non-null    object
#  5   body-style            205 non-null    object
#  6   drive-wheels          205 non-null    object
#  7   engine-location       205 non-null    object
#  8   wheel-base            205 non-null    float64
#  9    length               205 non-null    float64
#  10   width                205 non-null    float64
#  11  jheight               205 non-null    float64
#  12  curb-weigh            205 non-null    int64
#  13  engine-type           205 non-null    object
#  14   num-of-cylinders     205 non-null    object
# ...

# %%
df_copy = df.copy()
df_copy.tail()
# Out:
#    symboling normalized-losses    make  fuel-type aspirationaspiration  \
# -1        95             volvo     gas        std                 four
# -1        95             volvo     gas      turbo                 four
# -1        95             volvo     gas        std                 four
# -1        95             volvo  diesel      turbo                 four
# -1        95             volvo     gas      turbo                 four
#
#    body-style drive-wheels engine-location  wheel-base   length  ...  \
# -1      sedan          rwd           front       109.1    188.8  ...
# -1      sedan          rwd           front       109.1    188.8  ...
# -1      sedan          rwd           front       109.1    188.8  ...
# -1      sedan          rwd           front       109.1    188.8  ...
# -1      sedan          rwd           front       109.1    188.8  ...
#
#     engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# ...

# %%
df_copy.drop(['symboling','normalized-losses'], axis = 1, inplace =True)

# %%
df_copy.head()
# Out:
#   make  fuel-type aspirationaspiration   body-style drive-wheels  \
# 3  gas        std                  two  convertible          rwd
# 3  gas        std                  two  convertible          rwd
# 1  gas        std                  two    hatchback          rwd
# 2  gas        std                 four        sedan          fwd
# 2  gas        std                 four        sedan          4wd
#
#   engine-location  wheel-base   length   width  jheight  ...  engine-size  \
# 3           front        88.6    168.8    64.1     48.8  ...          130
# 3           front        88.6    168.8    64.1     48.8  ...          130
# 1           front        94.5    171.2    65.5     52.4  ...          152
# 2           front        99.8    176.6    66.2     54.3  ...          109
# 2           front        99.4    176.6    66.4     54.3  ...          136
#
#   fuel-system  bore  stroke compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
df_copy.columns
# Out:
# Index(['make', ' fuel-type', 'aspirationaspiration', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', ' length', ' width',
#        'jheight', 'curb-weigh', 'engine-type', ' num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', ' price'],
#       dtype='object')

# %%
df_new = df_copy[['make',' fuel-type',' length',' width','jheight','fuel-system','fuel-system',' price']]

# %%
df_new.head()
# Out:
#   make  fuel-type   length   width  jheight fuel-system fuel-system  price
# 3  gas        std    168.8    64.1     48.8        mpfi        mpfi  13495
# 3  gas        std    168.8    64.1     48.8        mpfi        mpfi  16500
# 1  gas        std    171.2    65.5     52.4        mpfi        mpfi  16500
# 2  gas        std    176.6    66.2     54.3        mpfi        mpfi  13950
# 2  gas        std    176.6    66.4     54.3        mpfi        mpfi  17450

# %%
y = df_new[' price']
y
# Out:
#  3    13495
#  3    16500
#  1    16500
#  2    13950
#  2    17450
#       ...
# -1    16845
# -1    19045
# -1    21485
# -1    22470
# -1    22625
# Name:  price, Length: 205, dtype: object

# %%
y.dtype
# Out:
# dtype('O')

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# Calculations of statistical parameters to describe a variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# parametre statisc usuels

# %%
#moyen
tips_df['tip'].mean()
# Out:
# 2.9982786885245902

# %%
#median
tips_df['tip'].median()
# Out:
# 2.9

# %%
tips_df['tip'].min()
# Out:
# 1.0

# %%
tips_df['tip'].max()
# Out:
# 10.0

# %%
tips_df['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
tips_df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips_df['time'].value_counts(normalize = True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %%
tips_df['tip'].max() - tips_df['tip'].min()
# Out:
# 9.0

# %%
tips_df['tip'].var()
# Out:
# 1.9144546380624725

# %%
tips_df['tip'].std() == (tips_df['tip'].var())**0.5
# Out:
# True

# %%
tips_df['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
tips_df.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
print('1er quartile:', tips_df['total_bill'].quantile(0.25))
print('2eme quartile:', tips_df['total_bill'].quantile(0.5))
print('3eme quartile:', tips_df['total_bill'].quantile(0.75))
# Out:
# 1er quartile: 13.3475
# 2eme quartile: 17.795
# 3eme quartile: 24.127499999999998

# %%
print('1er quartile:', np.quantile(tips_df['total_bill'], 0.25))
print('2eme quartile:', np.quantile(tips_df['total_bill'], 0.5))
print('3eme quartile:', np.quantile(tips_df['total_bill'], 0.75))
# Out:
# 1er quartile: 13.3475
# 2eme quartile: 17.795
# 3eme quartile: 24.127499999999998

# %%
print('1er quartile:', np.percentile(tips_df['total_bill'], 25))
print('2eme quartile:', np.percentile(tips_df['total_bill'], 50))
print('3eme quartile:', np.percentile(tips_df['total_bill'], 75))
# Out:
# 1er quartile: 13.3475
# 2eme quartile: 17.795
# 3eme quartile: 24.127499999999998

# %%
np.quantile(tips_df['total_bill'], [0.25, 0.5, 0.75])
# Out:
# array([13.3475, 17.795 , 24.1275])

# %%
np.quantile(tips_df['total_bill'], [0.2, 0.4, 0.6, 0.8, 1])
# Out:
# array([12.636, 16.222, 19.818, 26.098, 50.81 ])

# %%
#IQR c'est le 3 eme qantile - 1 ere qantile4
tips_df['total_bill'].quantile(0.75) - tips_df['total_bill'].quantile(0.25)
# Out:
# 10.779999999999998

# %%
from scipy import stats
stats.iqr(tips_df['total_bill'])
# Out:
# 10.779999999999998

# %%
tips_df.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
sat_sun_df = tips_df[(tips_df.day == 'Sat') | (tips_df.day == 'Sun') ]
sat_sun_df
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
sat_sun_df.groupby('day')['total_bill'].agg(['mean', 'median'])
# Out:
#            mean  median
# day
# Thur        NaN     NaN
# Fri         NaN     NaN
# Sat   20.441379   18.24
# Sun   21.410000   19.63

# %%
#basic graphic to write variable
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df .head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Histogramme pour voir la construbution de la variable quantitative continue
sns.histplot(tips_df['total_bill'], kde=False).set_title('Total Bill')
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
ax = sns.displot(tips_df['total_bill'], kde=False, bins=20)
ax.set(title='consommation totale')

# %%
sns.displot(
    tips_df['total_bill']).fig.suptitle('cosommation totale');

# %%
#importation Model stats Scipy

from scipy import stats 






#fonction pour trouver les outliers
def finding_outliers(data, variable_name):
    '''
    data : dataframe pandas
    variable_name : nom de la variable dans chaine de caracteres
    '''
    #calcul L'IQR , qe Q1 et Q3
    iqr = stats.iq(data[variable_name])
    q1 = data[varname].quantile(0.25)
    q3 = data[varname].quantile(0.75)
    #calcul de Q1 -1.5IQR et Q3 -1.5IQR
    lower = q1 -1.5 * iqr 
    upper = q3 -1.5 * iqr 
    #dataframe des valeurs oberrantes
    outliers_df = data[data[varname] < lower | (data[variable_name] > upper )]
    return outliers_df

# %%
# detrmine les points de donner aberrrantes d ela variable indiquant les pourboires
import numpy as np

# Calculate the interquartile range (IQR)
Q1 = tips['tip'].quantile(0.25)
Q3 = tips['tip'].quantile(0.75)
IQR = Q3 - Q1

# Identify potential outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = tips[(tips_df['tip'] < lower_bound) | (tips_df['tip'] > upper_bound)]

print("Potential outliers in 'tip' variable:")
print(outlier)
# Out:
# Potential outliers in 'tip' variable:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 239       29.03   5.92    Male     No   Sat  Dinner     3
